# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x = np.arange(-9000,9000, 1)
y =  np.sin(x)**2 +  2*x**2 + 5
print(y)
plt.plot(x,y)
# Out:
# [1.62000005e+08 1.61964008e+08 1.61928013e+08 ... 1.61892023e+08
#  1.61928013e+08 1.61964008e+08]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

print(x_train)
# Out:
# [  -38 -4480  5957 ... -3610 -8140  6795]

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

regr = LinearRegression()
regr.fit(x_train.reshape(-1,1), y_train)

y_pred = regr.predict(x_test.reshape(-1,1))

# %%
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
print('Coefficients: \n', regr.coef_)
# Out:
# Mean squared error: 2309135294404105.50
# Variance score: -0.00
# Coefficients:
#  [5.53762927]

# %%
plt.scatter(x_test, y_test,  color='black')
plt.plot(x_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
Xtrain_ = poly.fit_transform(x_train.reshape(-1,1))
#predict_ = poly.fit_transform(predict)
Xtest_ = poly.fit_transform(x_test.reshape(-1,1))
regr = LinearRegression()
regr.fit(Xtrain_, y_train)

y_pred = regr.predict(Xtest_)

# %%
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
print('Coefficients: \n', regr.coef_)
# Out:
# Mean squared error: 0.12
# Variance score: 1.00
# Coefficients:
#  [0.00000000e+00 5.36231237e-07 2.00000000e+00]

# %%
plt.scatter(x_test, y_test,  color='black')
plt.plot(x_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
